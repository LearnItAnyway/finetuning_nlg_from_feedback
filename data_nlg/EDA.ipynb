# %% [markdown]
# # Info
# ### The dataset used in the demo is from [aihub](https://aihub.or.kr/aihubdata/data/view.do?currMenu=115&topMenu=100&aihubDataSe=realm&dataSetSn=86)
# We use korean casual conversation data.
#
# 데모에 사용된 데이터셋은 [aihub](https://aihub.or.kr/aihubdata/data/view.do?currMenu=115&topMenu=100&aihubDataSe=realm&dataSetSn=86)의 대화 데이터입니다.

# %%
import pandas as pd
train_df = pd.read_csv('train_simple.csv')
valid_df = pd.read_csv('valid_simple.csv')

# %%
train_df
# Out:
#                                                 Q  \
# 0                            요즘 다른나라는 전기차를 많이 타요?
# 1                             아무래도 친환경 정책 때문 같아요.
# 2                        친환경 정책이요? 자세히 설명 좀 해주세요.
# 3        아니 별거 없어요. 석탄을 많이 쓰지말고 친환경 정책으로 가라는 거에요.
# 4                     저도 알고는 있어요. 어디서 먼저 시작 한거에요?
# ...                                           ...
# 1357999                  나는 아직 일본어를 잘 못하는데도 괜찮을까?
# 1358000                        응 들으면서 실력이 늘게 되어있어
# 1358001                         자막 같은 것은 보는게 좋을까?
# 1358002                             처음에는 보는게 편할거야
# 1358003                고마워. 모르는게 있으면 언니한테 물어봐야겠다.
#
#                                                 A
# 0                             아무래도 친환경 정책 때문 같아요.
# 1                        친환경 정책이요? 자세히 설명 좀 해주세요.
# 2        아니 별거 없어요. 석탄을 많이 쓰지말고 친환경 정책으로 가라는 거에요.
# 3                     저도 알고는 있어요. 어디서 먼저 시작 한거에요?
# 4                  너나 할 것 없이 요즘은 선진국이면 다 시작하더라고요.
# ...                                           ...
# ...

# %%
valid_df
# Out:
#                                                          Q  \
# 0                                     요즘 다른나라는 전기차를 많이 타요?
# 1                                      아무래도 친환경 정책 때문 같아요.
# 2                                 친환경 정책이요? 자세히 설명 좀 해주세요.
# 3                 아니 별거 없어요. 석탄을 많이 쓰지말고 친환경 정책으로 가라는 거에요.
# 4                              저도 알고는 있어요. 어디서 먼저 시작 한거에요?
# ...                                                    ...
# 1559050                             대전 와... 행복한 도시 대전이야...
# 1559051                      난 죽어도 서울에서 살고 싶지 않아 서울 싫어 ㅠ0ㅠ
# 1559052                  키키 누나 지금 살고 있는 곳은 투룸이야? 원룸 분리형이야?
# 1559053  투룸! 방 2개 거실 하나라서 친구랑 딱 살기 좋지 너네 집이랑 비슷한데 거실은 좀...
# 1559054                               키키 하지만 이제 곧 원룸순이 8ㅅ8
#
#                                                          A
# 0                                      아무래도 친환경 정책 때문 같아요.
# 1                                 친환경 정책이요? 자세히 설명 좀 해주세요.
# 2                 아니 별거 없어요. 석탄을 많이 쓰지말고 친환경 정책으로 가라는 거에요.
# ...

# %%
# The data has been removed to prevent some problems
pd.DataFrame({'Q':['' for _ in range(10)], 'A':['' for _ in range(10)]}).to_csv('train_simple.csv')
pd.DataFrame({'Q':['' for _ in range(10)], 'A':['' for _ in range(10)]}).to_csv('valid_simple.csv')
